# %% [markdown]
# <a href="https://colab.research.google.com/github/gitblankhub/Baf/blob/main/%EB%94%B0%EB%A6%89%EC%9D%B4project/%E1%84%84%E1%85%A1%E1%84%85%E1%85%B3%E1%86%BC%E1%84%8B%E1%85%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
os.getcwd()
os.chdir('/content/gdrive/MyDrive/Colab Notebooks/따릉이')

# %%
# package
import seaborn as sns
import numpy as np

import pandas as pd # 판다스 패키지

# %% [markdown]
# # 따릉이

# %%
# 파일 읽기
train=pd.read_csv('./따릉이data/train.csv') # 모델 학습 파일
test=pd.read_csv('./따릉이data/test.csv') # 모델 시험지 파일
submission = pd.read_csv('./따릉이data/submission.csv') # 답안지 파일

# %% [markdown]
# # EDA

# %% [markdown]
# ## 탐색적 자료분석

# %%
train.head()
# Out:
#    id  hour  hour_bef_temperature  hour_bef_precipitation  hour_bef_windspeed  \
# 0   3    20                  16.3                     1.0                 1.5
# 1   6    13                  20.1                     0.0                 1.4
# 2   7     6                  13.9                     0.0                 0.7
# 3   8    23                   8.1                     0.0                 2.7
# 4   9    18                  29.5                     0.0                 4.8
#
#    hour_bef_humidity  hour_bef_visibility  hour_bef_ozone  hour_bef_pm10  \
# 0               89.0                576.0           0.027           76.0
# 1               48.0                916.0           0.042           73.0
# 2               79.0               1382.0           0.033           32.0
# 3               54.0                946.0           0.040           75.0
# 4                7.0               2000.0           0.057           27.0
#
#    hour_bef_pm2.5  count
# 0            33.0   49.0
# 1            40.0  159.0
# 2            19.0   26.0
# 3            64.0   57.0
# 4            11.0  431.0

# %%
test.head()
# Out:
#    id  hour  hour_bef_temperature  hour_bef_precipitation  hour_bef_windspeed  \
# 0   0     7                  20.7                     0.0                 1.3
# 1   1    17                  30.0                     0.0                 5.4
# 2   2    13                  19.0                     1.0                 2.1
# 3   4     6                  22.5                     0.0                 2.5
# 4   5    22                  14.6                     1.0                 3.4
#
#    hour_bef_humidity  hour_bef_visibility  hour_bef_ozone  hour_bef_pm10  \
# 0               62.0                954.0           0.041           44.0
# 1               33.0               1590.0           0.061           49.0
# 2               95.0                193.0           0.020           36.0
# 3               60.0               1185.0           0.027           52.0
# 4               93.0                218.0           0.041           18.0
#
#    hour_bef_pm2.5
# 0            27.0
# 1            36.0
# 2            28.0
# 3            38.0
# 4            15.0

# %%
submission.head()
# Out:
#    id  count
# 0   0    NaN
# 1   1    NaN
# 2   2    NaN
# 3   4    NaN
# 4   5    NaN

# %% [markdown]
# * preciptation : 비 정보. 비 안오면 0 비오면 1
# * visibility : 시정, 시계
# * count : 따릉이 대여수
#
# - count 를 예측. (train을 바탕으로 test)

# %% [markdown]
# ### 데이터 크기

# %%
print(train.shape)
print(test.shape) # count 열 없음
print(submission.shape) # test 셋의 count 값을 submission(답안지)에
# Out:
# (1459, 11)
# (715, 10)
# (715, 2)

# %% [markdown]
# ### 결측값 확인

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1459 non-null   int64
#  1   hour                    1459 non-null   int64
#  2   hour_bef_temperature    1457 non-null   float64
#  3   hour_bef_precipitation  1457 non-null   float64
#  4   hour_bef_windspeed      1450 non-null   float64
#  5   hour_bef_humidity       1457 non-null   float64
#  6   hour_bef_visibility     1457 non-null   float64
#  7   hour_bef_ozone          1383 non-null   float64
#  8   hour_bef_pm10           1369 non-null   float64
#  9   hour_bef_pm2.5          1342 non-null   float64
#  10  count                   1459 non-null   float64
# dtypes: float64(9), int64(2)
# memory usage: 125.5 KB

# %% [markdown]
# id hour (1459obs) 제외 결측치 존재

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 715 entries, 0 to 714
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      715 non-null    int64
#  1   hour                    715 non-null    int64
#  2   hour_bef_temperature    714 non-null    float64
#  3   hour_bef_precipitation  714 non-null    float64
#  4   hour_bef_windspeed      714 non-null    float64
#  5   hour_bef_humidity       714 non-null    float64
#  6   hour_bef_visibility     714 non-null    float64
#  7   hour_bef_ozone          680 non-null    float64
#  8   hour_bef_pm10           678 non-null    float64
#  9   hour_bef_pm2.5          679 non-null    float64
# dtypes: float64(8), int64(2)
# memory usage: 56.0 KB

# %%
train.describe()
# Out:
#                 id         hour  hour_bef_temperature  hour_bef_precipitation  \
# count  1459.000000  1459.000000           1457.000000             1457.000000
# mean   1105.914325    11.493489             16.717433                0.031572
# std     631.338681     6.922790              5.239150                0.174917
# min       3.000000     0.000000              3.100000                0.000000
# 25%     555.500000     5.500000             12.800000                0.000000
# 50%    1115.000000    11.000000             16.600000                0.000000
# 75%    1651.000000    17.500000             20.100000                0.000000
# max    2179.000000    23.000000             30.000000                1.000000
#
#        hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# count         1450.000000        1457.000000          1457.000000
# mean             2.479034          52.231297          1405.216884
# std              1.378265          20.370387           583.131708
# min              0.000000           7.000000            78.000000
# 25%              1.400000          36.000000           879.000000
# 50%              2.300000          51.000000          1577.000000
# 75%              3.400000          69.000000          1994.000000
# max              8.000000          99.000000          2000.000000
#
#        hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5        count
# count     1383.000000    1369.000000     1342.000000  1459.000000
# mean         0.039149      57.168736       30.327124   108.563400
# std          0.019509      31.771019       14.713252    82.631733
# min          0.003000       9.000000        8.000000     1.000000
# 25%          0.025500      36.000000       20.000000    37.000000
# 50%          0.039000      51.000000       26.000000    96.000000
# 75%          0.052000      69.000000       37.000000   150.000000
# max          0.125000     269.000000       90.000000   431.000000

# %%
test.describe()
# Out:
#                 id        hour  hour_bef_temperature  hour_bef_precipitation  \
# count   715.000000  715.000000            714.000000              714.000000
# mean   1056.854545   11.472727             23.263305                0.051821
# std     625.574471    6.928427              4.039645                0.221820
# min       0.000000    0.000000             14.600000                0.000000
# 25%     507.000000    5.500000             20.300000                0.000000
# 50%    1046.000000   11.000000             22.900000                0.000000
# 75%    1616.500000   17.000000             26.375000                0.000000
# max    2177.000000   23.000000             33.800000                1.000000
#
#        hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# count          714.000000         714.000000           714.000000
# mean             2.388515          56.668067          1359.494398
# std              1.171270          19.661880           614.171870
# min              0.000000          16.000000           126.000000
# 25%              1.500000          42.000000           807.250000
# 50%              2.300000          55.000000          1489.000000
# 75%              3.275000          73.750000          2000.000000
# max              5.900000         100.000000          2000.000000
#
#        hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5
# count      680.000000     678.000000      679.000000
# mean         0.041196      36.930678       24.939617
# std          0.020656      12.641503       10.075857
# min          0.003000       9.000000        7.000000
# 25%          0.027000      28.000000       17.000000
# 50%          0.039000      35.000000       24.000000
# 75%          0.052250      45.000000       31.000000
# max          0.138000      94.000000       69.000000

# %% [markdown]
# ##### 시간별로 따릉이 대여량 평균

# %%
train.groupby('hour').mean()
# Out:
#                id  hour_bef_temperature  hour_bef_precipitation  \
# hour
# 0     1200.016667             14.788136                0.016949
# 1     1074.918033             14.155738                0.049180
# 2     1077.885246             13.747541                0.049180
# 3     1146.704918             13.357377                0.032787
# 4     1194.786885             13.001639                0.016393
# 5     1091.819672             12.673770                0.016393
# 6     1112.393443             12.377049                0.016393
# 7     1086.262295             12.191803                0.016393
# 8     1086.491803             12.600000                0.032787
# 9     1076.524590             14.318033                0.016393
# 10     965.704918             16.242623                0.016393
# 11    1208.803279             18.019672                0.000000
# 12    1149.639344             19.457377                0.016393
# 13     988.616667             20.648333                0.016667
# 14    1067.327869             21.234426                0.065574
# 15    1181.918033             21.744262                0.065574
# 16    1029.100000             22.015000                0.050000
# 17    1178.950000             21.603333                0.100000
# 18    1127.327869             20.926667                0.016667
# 19    1153.147541             19.704918                0.032787
# 20    1000.934426             18.191803                0.049180
# 21    1109.116667             16.978333                0.016667
# 22    1153.327869             16.063934                0.032787
# 23    1079.836066             15.418033                0.016393
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# hour
# 0               1.965517          58.169492          1434.220339
# 1               1.836667          60.459016          1400.852459
# 2               1.633333          61.721311          1374.278689
# 3               1.620000          63.131148          1326.311475
# 4               1.409836          64.573770          1264.606557
# 5               1.296721          66.000000          1203.426230
# 6               1.331148          67.409836          1146.229508
# 7               1.262295          67.934426          1150.311475
# 8               1.632787          64.049180          1152.868852
# 9               1.829508          57.803279          1189.098361
# 10              2.122951          51.622951          1291.295082
# 11              2.485246          46.262295          1358.868852
# 12              2.766667          42.147541          1469.606557
# 13              3.281356          38.850000          1512.266667
# 14              3.522951          37.573770          1519.721311
# 15              3.768852          37.393443          1528.065574
# 16              3.820000          36.450000          1566.583333
# 17              3.801667          38.883333          1561.733333
# 18              3.838333          40.450000          1581.850000
# 19              3.595082          43.573770          1576.688525
# 20              3.278333          47.573770          1565.557377
# 21              2.755000          50.450000          1590.016667
# 22              2.498361          53.950820          1512.081967
# 23              2.195082          56.393443          1462.508197
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5       count
# hour
# 0           0.033763      55.881356       30.982759   71.766667
# 1                NaN            NaN             NaN   47.606557
# 2           0.030492      58.475410       31.366667   31.409836
# 3           0.031213      59.180328       31.466667   21.377049
# 4           0.031984      58.278689       32.116667   13.524590
# 5           0.031623      56.721311       31.525424   13.114754
# 6           0.029317      56.150000       31.603448   24.557377
# 7           0.025300      56.533333       31.779661   62.360656
# 8           0.021197      57.918033       31.796610  136.688525
# 9           0.021492      59.147541       31.616667   93.540984
# 10          0.025167      61.083333       30.948276   78.803279
# 11          0.030367      60.300000       30.827586   88.327869
# 12          0.036817      59.344828       29.280702  111.901639
# 13          0.045203      59.589286       29.946429  120.050000
# 14          0.053344      58.283333       29.844828  134.590164
# 15          0.057400      57.355932       28.741379  152.967213
# 16          0.060579      57.315789       27.910714  169.100000
# 17          0.060362      57.086207       28.553571  187.133333
# 18          0.058508      56.875000       29.127273  262.163934
# 19          0.053967      53.847458       28.338983  201.606557
# 20          0.048279      53.118644       28.850000  164.868852
# 21          0.043517      53.933333       29.694915  168.816667
# 22          0.038066      54.098361       30.216667  148.245902
# 23          0.035148      54.426230       30.593220  103.852459

# %%
train.groupby('hour').mean()['count']
# Out:
# hour
# 0      71.766667
# 1      47.606557
# 2      31.409836
# 3      21.377049
# 4      13.524590
# 5      13.114754
# 6      24.557377
# 7      62.360656
# 8     136.688525
# 9      93.540984
# 10     78.803279
# 11     88.327869
# 12    111.901639
# 13    120.050000
# 14    134.590164
# 15    152.967213
# 16    169.100000
# 17    187.133333
# 18    262.163934
# 19    201.606557
# 20    164.868852
# 21    168.816667
# 22    148.245902
# 23    103.852459
# Name: count, dtype: float64

# %%
# 시간대별 데이터 개수
train.groupby('hour').count()
# Out:
#       id  hour_bef_temperature  hour_bef_precipitation  hour_bef_windspeed  \
# hour
# 0     60                    59                      59                  58
# 1     61                    61                      61                  60
# 2     61                    61                      61                  60
# 3     61                    61                      61                  60
# 4     61                    61                      61                  61
# 5     61                    61                      61                  61
# 6     61                    61                      61                  61
# 7     61                    61                      61                  61
# 8     61                    61                      61                  61
# 9     61                    61                      61                  61
# 10    61                    61                      61                  61
# 11    61                    61                      61                  61
# 12    61                    61                      61                  60
# 13    60                    60                      60                  59
# 14    61                    61                      61                  61
# 15    61                    61                      61                  61
# 16    60                    60                      60                  60
# 17    60                    60                      60                  60
# 18    61                    60                      60                  60
# 19    61                    61                      61                  61
# 20    61                    61                      61                  60
# 21    60                    60                      60                  60
# 22    61                    61                      61                  61
# 23    61                    61                      61                  61
#
#       hour_bef_humidity  hour_bef_visibility  hour_bef_ozone  hour_bef_pm10  \
# hour
# 0                    59                   59              59             59
# 1                    61                   61               0              0
# 2                    61                   61              61             61
# 3                    61                   61              61             61
# 4                    61                   61              61             61
# 5                    61                   61              61             61
# 6                    61                   61              60             60
# 7                    61                   61              60             60
# 8                    61                   61              61             61
# 9                    61                   61              61             61
# 10                   61                   61              60             60
# 11                   61                   61              60             60
# 12                   61                   61              60             58
# 13                   60                   60              59             56
# 14                   61                   61              61             60
# 15                   61                   61              60             59
# 16                   60                   60              57             57
# 17                   60                   60              58             58
# 18                   60                   60              59             56
# 19                   61                   61              61             59
# 20                   61                   61              61             59
# 21                   60                   60              60             60
# 22                   61                   61              61             61
# 23                   61                   61              61             61
#
#       hour_bef_pm2.5  count
# hour
# 0                 58     60
# 1                  0     61
# 2                 60     61
# 3                 60     61
# 4                 60     61
# 5                 59     61
# 6                 58     61
# 7                 59     61
# 8                 59     61
# 9                 60     61
# 10                58     61
# 11                58     61
# 12                57     61
# 13                56     60
# 14                58     61
# 15                58     61
# 16                56     60
# 17                56     60
# 18                55     61
# 19                59     61
# 20                60     61
# 21                59     60
# 22                60     61
# 23                59     61

# %% [markdown]
# ### 시각화

# %%
# 시각화
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))
plt.plot(train['hour'],train['count'],'*',data=train,color='lightseagreen')

plt.title('average count by hour')
plt.xlabel('hour')
plt.ylabel('count')

plt.axvline(8,color='red') #vertical line
plt.axvline(18,color='red')

plt.show()

# %% [markdown]
# 출근/등교시간이나 퇴근/하교시간에 많음

# %%
plt.plot(train.groupby('hour').mean()['count'],marker='o',color='g')
plt.grid()

#제목 축
plt.title('average count by hour',fontsize=15)
plt.xlabel('hour')
plt.ylabel('count')

#위에 원하는 선
plt.axvline(8,color='red') #vertical line
plt.axvline(18,color='red')

#원하는 텍스트
plt.text(8,150,'go work')
plt.text(18,260,'go home')
plt.show()

# %% [markdown]
# 시간이 증가할수록 대여량 증가

# %% [markdown]
# 변수간에 상관관계 표현 (상관계수)
# * -1 ~ 1

# %%
plt.figure(figsize=(10,10))

# Use bool instead of np.bool
mask = np.zeros_like(train.corr(), dtype=bool)
mask[np.triu_indices_from(mask)] = False

sns.heatmap(train.corr(),annot=True)
plt.show()

# %% [markdown]
# count 상관계수 높은 hour, temp, windspeed 사용 + humidity & ozone

# %% [markdown]
# * 추가 몇몇 그래프

# %% [markdown]
# ### 이상치 확인

# %%
sns.boxplot(y='count',data=train)
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

sns.boxplot(y='hour_bef_temperature',data=train,ax=ax1)
sns.boxplot(y='hour_bef_windspeed',data=train,ax=ax2)
plt.show()

# %%
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)
sns.boxplot(y='hour_bef_humidity',data=train,ax=ax1)
sns.boxplot(y='hour_bef_visibility',data=train,ax=ax2)
sns.boxplot(y='hour_bef_ozone',data=train,ax=ax3)
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

sns.boxplot(y='hour_bef_pm10',data=train,ax=ax1)
sns.boxplot(y='hour_bef_pm2.5',data=train,ax=ax2)
plt.show()

# %%
fig = plt.figure(figsize=(15,7))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

sns.boxplot(y='hour_bef_windspeed',data=train,ax=ax1,color='lightseagreen').set_title('windspeed outlier',fontsize=20)

sns.boxplot(y='hour_bef_ozone',data=train,ax=ax2,color='mediumturquoise').set_title('ozone outlier',fontsize=20)

plt.axhline(0.151,color='red')
plt.text(0.4,0.153,'0.151~',color='red')

plt.show()

# %%
fig = plt.figure(figsize=(15,7))
ax1 = fig.add_subplot(1,2,1)


sns.boxplot(y='hour_bef_pm10',data=train,ax=ax1,color='lightseagreen').set_title('pm10 outlier',fontsize=20)
plt.axhline(151,color='red')
plt.text(0.4,153,'151~',color='red')

ax2 = fig.add_subplot(1,2,2)
sns.boxplot(y='hour_bef_pm2.5',data=train,ax=ax2,color='mediumturquoise').set_title('pm2.5 outlier',fontsize=20)
plt.axhline(76,color='red')
plt.text(0.4,77,'76~',color='red')

plt.show()

# %%
train[train['hour_bef_pm10']>200]
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 49      83     6                  11.0                     0.0
# 120    179     3                  13.2                     0.0
# 233    365    14                  23.1                     0.0
# 343    527     9                  13.4                     0.0
# 446    690    12                  21.4                     0.0
# 617    947     4                  12.3                     0.0
# 653   1000     5                  11.8                     0.0
# 680   1038    16                  22.8                     0.0
# 1061  1597    13                  23.2                     0.0
# 1263  1911     2                  14.2                     0.0
# 1296  1961     7                  10.1                     0.0
# 1379  2068    15                  23.3                     0.0
# 1383  2075     8                  10.6                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 49                   1.3               25.0               1056.0
# 120                  2.5               25.0                950.0
# 233                  3.6               44.0                620.0
# 343                  2.6               21.0                986.0
# 446                  3.0               46.0                565.0
# 617                  2.8               22.0               1082.0
# 653                  2.5               21.0               1014.0
# 680                  4.3               40.0                716.0
# 1061                 3.7               45.0                527.0
# 1263                 4.9               33.0                660.0
# 1296                 0.9               29.0               1078.0
# 1379                 3.6               45.0                680.0
# 1383                 0.7               22.0                974.0
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  count
# 49             0.041          213.0            21.0   12.0
# 120            0.041          269.0            21.0   16.0
# 233            0.080          237.0            62.0   91.0
# 343            0.027          212.0            20.0   59.0
# 446            0.064          213.0            57.0  104.0
# 617            0.042          223.0            20.0   16.0
# 653            0.042          205.0            18.0    6.0
# 680            0.075          212.0             NaN  135.0
# 1061           0.069          225.0            61.0   91.0
# 1263           0.041          252.0            31.0   26.0
# 1296           0.038          223.0            22.0   13.0
# 1379           0.074          220.0            51.0  108.0
# 1383           0.026          214.0            21.0   34.0

# %%
#outlier

def out(df=None,col=None):
  q1=df[col].quantile(q=0.25)
  q3=df[col].quantile(q=0.75)
  iqr=q3-q1

  low=-3*iqr+q1
  high=q3+3*iqr

  lowout = df[(df[col] < low)]
  highout = df[(df[col] > high)]
  print(lowout)
  print(highout)

# %%
out(train,'hour_bef_ozone')
# Out:
# Empty DataFrame
# Columns: [id, hour, hour_bef_temperature, hour_bef_precipitation, hour_bef_windspeed, hour_bef_humidity, hour_bef_visibility, hour_bef_ozone, hour_bef_pm10, hour_bef_pm2.5, count]
# Index: []
# Empty DataFrame
# Columns: [id, hour, hour_bef_temperature, hour_bef_precipitation, hour_bef_windspeed, hour_bef_humidity, hour_bef_visibility, hour_bef_ozone, hour_bef_pm10, hour_bef_pm2.5, count]
# Index: []

# %%
out(train,'hour_bef_pm10')
# Out:
# Empty DataFrame
# Columns: [id, hour, hour_bef_temperature, hour_bef_precipitation, hour_bef_windspeed, hour_bef_humidity, hour_bef_visibility, hour_bef_ozone, hour_bef_pm10, hour_bef_pm2.5, count]
# Index: []
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 20      35    10                  15.4                     0.0
# 49      83     6                  11.0                     0.0
# 62      97    21                  18.6                     0.0
# 120    179     3                  13.2                     0.0
# 183    280    11                  19.6                     0.0
# 233    365    14                  23.1                     0.0
# 234    366    17                  22.3                     0.0
# 280    437    20                  19.3                     0.0
# 343    527     9                  13.4                     0.0
# 446    690    12                  21.4                     0.0
# 617    947     4                  12.3                     0.0
# 653   1000     5                  11.8                     0.0
# 680   1038    16                  22.8                     0.0
# 877   1335    19                  20.2                     0.0
# 879   1337    16                  18.7                     0.0
# 1061  1597    13                  23.2                     0.0
# 1099  1660    22                  18.3                     0.0
# 1226  1852    18                  21.1                     0.0
# 1263  1911     2                  14.2                     0.0
# 1279  1936    11                  16.8                     0.0
# 1296  1961     7                  10.1                     0.0
# 1379  2068    15                  23.3                     0.0
# 1383  2075     8                  10.6                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 20                   3.1               19.0               1225.0
# 49                   1.3               25.0               1056.0
# 62                   2.3               35.0                987.0
# 120                  2.5               25.0                950.0
# 183                  2.9               50.0                602.0
# 233                  3.6               44.0                620.0
# 234                  2.7               42.0                819.0
# 280                  2.4               36.0                935.0
# 343                  2.6               21.0                986.0
# 446                  3.0               46.0                565.0
# 617                  2.8               22.0               1082.0
# 653                  2.5               21.0               1014.0
# 680                  4.3               40.0                716.0
# 877                  3.0               40.0                928.0
# 879                  4.9               36.0               1036.0
# 1061                 3.7               45.0                527.0
# 1099                 1.0               37.0                970.0
# 1226                 3.3               42.0                832.0
# 1263                 4.9               33.0                660.0
# 1279                 4.2               16.0               1228.0
# 1296                 0.9               29.0               1078.0
# 1379                 3.6               45.0                680.0
# 1383                 0.7               22.0                974.0
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  count
# 20             0.032          199.0            18.0   58.0
# 49             0.041          213.0            21.0   12.0
# 62             0.031          178.0            37.0  139.0
# 120            0.041          269.0            21.0   16.0
# 183            0.061          193.0            54.0   66.0
# 233            0.080          237.0            62.0   91.0
# 234            0.073          200.0             NaN  151.0
# 280            0.046          176.0            39.0  123.0
# 343            0.027          212.0            20.0   59.0
# 446            0.064          213.0            57.0  104.0
# 617            0.042          223.0            20.0   16.0
# 653            0.042          205.0            18.0    6.0
# 680            0.075          212.0             NaN  135.0
# 877            0.058          180.0            40.0  187.0
# 879            0.048          197.0            22.0   74.0
# 1061           0.069          225.0            61.0   91.0
# 1099           0.032          169.0            38.0  172.0
# 1226           0.064          192.0             NaN  236.0
# 1263           0.041          252.0            31.0   26.0
# 1279           0.031          197.0            22.0   67.0
# 1296           0.038          223.0            22.0   13.0
# 1379           0.074          220.0            51.0  108.0
# 1383           0.026          214.0            21.0   34.0

# %%
out(train,'hour_bef_pm2.5')
# Out:
# Empty DataFrame
# Columns: [id, hour, hour_bef_temperature, hour_bef_precipitation, hour_bef_windspeed, hour_bef_humidity, hour_bef_visibility, hour_bef_ozone, hour_bef_pm10, hour_bef_pm2.5, count]
# Index: []
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 428    666    12                  13.8                     0.0
# 511    787     4                  12.3                     0.0
# 1155  1743     8                  15.3                     0.0
# 1191  1796    13                  15.7                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 428                  2.8               42.0                516.0
# 511                  1.5               36.0                966.0
# 1155                 1.5               68.0                272.0
# 1191                 3.3               37.0                526.0
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  count
# 428            0.031          104.0            89.0   82.0
# 511            0.024           96.0            90.0   14.0
# 1155           0.026          142.0            89.0  163.0
# 1191           0.047          105.0            90.0   75.0

# %%
sns.boxplot(x='hour_bef_precipitation', y='count', data=train)
plt.show()

# %%
# 비 여부에 따른 평균대여량
train.groupby('hour_bef_precipitation').mean()['count']
# Out:
# hour_bef_precipitation
# 0.0    111.130404
# 1.0     33.673913
# Name: count, dtype: float64

# %%
sns.barplot(x='hour', y='count', hue='hour_bef_precipitation', dodge=False, data=train) #dodge 누적
plt.show()

# %% [markdown]
# # 전처리 - NA

# %%
train1=train

# %%
train1.isna().sum()
# Out:
# id                          0
# hour                        0
# hour_bef_temperature        2
# hour_bef_precipitation      2
# hour_bef_windspeed          9
# hour_bef_humidity           2
# hour_bef_visibility         2
# hour_bef_ozone             76
# hour_bef_pm10              90
# hour_bef_pm2.5            117
# count                       0
# dtype: int64

# %% [markdown]
# ### 결측치 처리

# %% [markdown]
# `fillna()` 함수로 결측치 대체

# %% [markdown]
# #### train dataset

# %% [markdown]
# ##### temperature NA

# %%
train1[train1['hour_bef_temperature'].isna()]
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 934   1420     0                   NaN                     NaN
# 1035  1553    18                   NaN                     NaN
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 934                  NaN                NaN                  NaN
# 1035                 NaN                NaN                  NaN
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  count
# 934              NaN            NaN             NaN   39.0
# 1035             NaN            NaN             NaN    1.0

# %%
tna = train1[train1['hour_bef_temperature'].isna()].index
tna
# Out:
# Index([934, 1035], dtype='int64')

# %%
train1 = train1.drop(tna) # 결측지 제거

# %%
train1[train1['hour_bef_temperature'].isna()]
# Out:
# Empty DataFrame
# Columns: [id, hour, hour_bef_temperature, hour_bef_precipitation, hour_bef_windspeed, hour_bef_humidity, hour_bef_visibility, hour_bef_ozone, hour_bef_pm10, hour_bef_pm2.5, count]
# Index: []

# %%
# 더미변수 생성
tdum = pd.get_dummies(train1['hour'])
train1 = train1.join(tdum.add_prefix('hour_'))
train1
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 0        3    20                  16.3                     1.0
# 1        6    13                  20.1                     0.0
# 2        7     6                  13.9                     0.0
# 3        8    23                   8.1                     0.0
# 4        9    18                  29.5                     0.0
# ...    ...   ...                   ...                     ...
# 1454  2174     4                  16.8                     0.0
# 1455  2175     3                  10.8                     0.0
# 1456  2176     5                  18.3                     0.0
# 1457  2178    21                  20.7                     0.0
# 1458  2179    17                  21.1                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 0                    1.5               89.0                576.0
# 1                    1.4               48.0                916.0
# 2                    0.7               79.0               1382.0
# 3                    2.7               54.0                946.0
# 4                    4.8                7.0               2000.0
# ...                  ...                ...                  ...
# 1454                 1.6               53.0               2000.0
# 1455                 3.8               45.0               2000.0
# 1456                 1.9               54.0               2000.0
# 1457                 3.7               37.0               1395.0
# 1458                 3.1               47.0               1973.0
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  ...  hour_14  hour_15  \
# 0              0.027           76.0            33.0  ...    False    False
# 1              0.042           73.0            40.0  ...    False    False
# 2              0.033           32.0            19.0  ...    False    False
# 3              0.040           75.0            64.0  ...    False    False
# 4              0.057           27.0            11.0  ...    False    False
# ...              ...            ...             ...  ...      ...      ...
# 1454           0.031           37.0            27.0  ...    False    False
# 1455           0.039           34.0            19.0  ...    False    False
# 1456           0.009           30.0            21.0  ...    False    False
# 1457           0.082           71.0            36.0  ...    False    False
# 1458           0.046           38.0            17.0  ...    False    False
#
#       hour_16  hour_17  hour_18  hour_19  hour_20  hour_21  hour_22  hour_23
# 0       False    False    False    False     True    False    False    False
# 1       False    False    False    False    False    False    False    False
# 2       False    False    False    False    False    False    False    False
# 3       False    False    False    False    False    False    False     True
# 4       False    False     True    False    False    False    False    False
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1454    False    False    False    False    False    False    False    False
# 1455    False    False    False    False    False    False    False    False
# 1456    False    False    False    False    False    False    False    False
# 1457    False    False    False    False    False     True    False    False
# 1458    False     True    False    False    False    False    False    False
#
# [1457 rows x 35 columns]

# %% [markdown]
# ##### windspeed NA

# %%
# 풍속의 결측치 위치
train1[train1['hour_bef_windspeed'].isna()]
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 18      33    13                  22.6                     0.0
# 244    381     1                  14.1                     0.0
# 260    404     3                  14.0                     0.0
# 376    570     0                  14.3                     0.0
# 780   1196    20                  16.5                     0.0
# 1138  1717    12                  21.4                     0.0
# 1229  1855     2                  14.0                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 18                   NaN               41.0                987.0
# 244                  NaN               55.0               1992.0
# 260                  NaN               50.0               2000.0
# 376                  NaN               49.0               2000.0
# 780                  NaN               31.0               2000.0
# 1138                 NaN               44.0               1375.0
# 1229                 NaN               52.0               2000.0
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  ...  hour_14  hour_15  \
# 18             0.046           64.0            39.0  ...    False    False
# 244              NaN            NaN             NaN  ...    False    False
# 260            0.049           35.0            22.0  ...    False    False
# 376            0.044           37.0            20.0  ...    False    False
# 780            0.058           39.0            18.0  ...    False    False
# 1138           0.044           61.0            37.0  ...    False    False
# 1229           0.044           37.0            20.0  ...    False    False
#
#       hour_16  hour_17  hour_18  hour_19  hour_20  hour_21  hour_22  hour_23
# 18      False    False    False    False    False    False    False    False
# 244     False    False    False    False    False    False    False    False
# 260     False    False    False    False    False    False    False    False
# 376     False    False    False    False    False    False    False    False
# 780     False    False    False    False     True    False    False    False
# 1138    False    False    False    False    False    False    False    False
# 1229    False    False    False    False    False    False    False    False
#
# [7 rows x 35 columns]

# %% [markdown]
# 상관계수가 높은 ozone 을 이용해 결측치 제거
# 이때, 1시에서는 ozone값이 결측치

# %%
# 1시 경우에는 1시일때 windspeed의 median으로 대체
train1[train1['hour']==1]['hour_bef_windspeed'].median()
# Out:
# 1.65

# %%
train1.loc[244,'hour_bef_windspeed']=1.65
train1.loc[244,]
# Out:
# id                           381
# hour                           1
# hour_bef_temperature        14.1
# hour_bef_precipitation       0.0
# hour_bef_windspeed          1.65
# hour_bef_humidity           55.0
# hour_bef_visibility       1992.0
# hour_bef_ozone               NaN
# hour_bef_pm10                NaN
# hour_bef_pm2.5               NaN
# count                       38.0
# hour_0                     False
# hour_1                      True
# hour_2                     False
# hour_3                     False
# hour_4                     False
# hour_5                     False
# hour_6                     False
# hour_7                     False
# hour_8                     False
# hour_9                     False
# hour_10                    False
# hour_11                    False
# hour_12                    False
# hour_13                    False
# hour_14                    False
# hour_15                    False
# hour_16                    False
# hour_17                    False
# hour_18                    False
# hour_19                    False
# hour_20                    False
# hour_21                    False
# hour_22                    False
# hour_23                    False
# Name: 244, dtype: object

# %%
train1[train1['hour_bef_windspeed'].isna()]
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 18      33    13                  22.6                     0.0
# 260    404     3                  14.0                     0.0
# 376    570     0                  14.3                     0.0
# 780   1196    20                  16.5                     0.0
# 1138  1717    12                  21.4                     0.0
# 1229  1855     2                  14.0                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 18                   NaN               41.0                987.0
# 260                  NaN               50.0               2000.0
# 376                  NaN               49.0               2000.0
# 780                  NaN               31.0               2000.0
# 1138                 NaN               44.0               1375.0
# 1229                 NaN               52.0               2000.0
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  ...  hour_14  hour_15  \
# 18             0.046           64.0            39.0  ...    False    False
# 260            0.049           35.0            22.0  ...    False    False
# 376            0.044           37.0            20.0  ...    False    False
# 780            0.058           39.0            18.0  ...    False    False
# 1138           0.044           61.0            37.0  ...    False    False
# 1229           0.044           37.0            20.0  ...    False    False
#
#       hour_16  hour_17  hour_18  hour_19  hour_20  hour_21  hour_22  hour_23
# 18      False    False    False    False    False    False    False    False
# 260     False    False    False    False    False    False    False    False
# 376     False    False    False    False    False    False    False    False
# 780     False    False    False    False     True    False    False    False
# 1138    False    False    False    False    False    False    False    False
# 1229    False    False    False    False    False    False    False    False
#
# [6 rows x 35 columns]

# %%
# ozone 을 통해 windspeed 결측치
plt.scatter(x='hour_bef_ozone',y='hour_bef_windspeed',data=train1,color='lightseagreen')
plt.xlabel('ozone')
plt.ylabel('windspeed')
# Out:
# Text(0, 0.5, 'windspeed')

# %%
train1.groupby('hour_bef_ozone')['hour_bef_windspeed'].describe()
# Out:
#                 count      mean       std  min    25%  50%    75%  max
# hour_bef_ozone
# 0.003             4.0  1.475000  1.027538  0.1  1.000  1.7  2.175  2.4
# 0.004            20.0  1.145000  0.747258  0.1  0.475  1.0  1.725  2.8
# 0.005            17.0  1.335294  0.831370  0.2  0.800  1.0  1.800  3.1
# 0.006            16.0  1.162500  0.814760  0.3  0.600  0.9  1.700  3.6
# 0.007            11.0  1.400000  0.869483  0.4  0.900  1.3  1.650  3.5
# ...               ...       ...       ...  ...    ...  ...    ...  ...
# 0.099             2.0  3.800000  1.838478  2.5  3.150  3.8  4.450  5.1
# 0.100             3.0  3.300000  0.264575  3.1  3.150  3.2  3.400  3.6
# 0.106             1.0  4.100000       NaN  4.1  4.100  4.1  4.100  4.1
# 0.112             1.0  3.900000       NaN  3.9  3.900  3.9  3.900  3.9
# 0.125             1.0  4.400000       NaN  4.4  4.400  4.4  4.400  4.4
#
# [95 rows x 8 columns]

# %%
train1.groupby('hour_bef_ozone')['hour_bef_windspeed'].median().isna().sum()
# Out:
# 0

# %%
train1[train1['hour_bef_ozone']==0.046]['hour_bef_windspeed'].describe()
# Out:
# count    17.000000
# mean      3.358824
# std       1.212466
# min       1.400000
# 25%       2.800000
# 50%       3.200000
# 75%       4.200000
# max       6.000000
# Name: hour_bef_windspeed, dtype: float64

# %%
train1[train1['hour_bef_ozone']==0.049]['hour_bef_windspeed'].describe()
# Out:
# count    28.000000
# mean      2.642857
# std       1.499735
# min       0.500000
# 25%       1.375000
# 50%       2.500000
# 75%       3.400000
# max       5.500000
# Name: hour_bef_windspeed, dtype: float64

# %%
train1[train1['hour_bef_ozone']==0.058]['hour_bef_windspeed'].describe()
# Out:
# count    14.000000
# mean      3.871429
# std       1.478267
# min       0.600000
# 25%       3.175000
# 50%       3.900000
# 75%       4.800000
# max       6.000000
# Name: hour_bef_windspeed, dtype: float64

# %%
train1[train1['hour_bef_ozone']==0.044]['hour_bef_windspeed'].describe()
# Out:
# count    29.000000
# mean      3.682759
# std       1.194950
# min       1.000000
# 25%       3.100000
# 50%       3.500000
# 75%       4.500000
# max       6.300000
# Name: hour_bef_windspeed, dtype: float64

# %%
train1[train1['hour_bef_windspeed'].isna()]
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 18      33    13                  22.6                     0.0
# 260    404     3                  14.0                     0.0
# 376    570     0                  14.3                     0.0
# 780   1196    20                  16.5                     0.0
# 1138  1717    12                  21.4                     0.0
# 1229  1855     2                  14.0                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 18                   NaN               41.0                987.0
# 260                  NaN               50.0               2000.0
# 376                  NaN               49.0               2000.0
# 780                  NaN               31.0               2000.0
# 1138                 NaN               44.0               1375.0
# 1229                 NaN               52.0               2000.0
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  ...  hour_14  hour_15  \
# 18             0.046           64.0            39.0  ...    False    False
# 260            0.049           35.0            22.0  ...    False    False
# 376            0.044           37.0            20.0  ...    False    False
# 780            0.058           39.0            18.0  ...    False    False
# 1138           0.044           61.0            37.0  ...    False    False
# 1229           0.044           37.0            20.0  ...    False    False
#
#       hour_16  hour_17  hour_18  hour_19  hour_20  hour_21  hour_22  hour_23
# 18      False    False    False    False    False    False    False    False
# 260     False    False    False    False    False    False    False    False
# 376     False    False    False    False    False    False    False    False
# 780     False    False    False    False     True    False    False    False
# 1138    False    False    False    False    False    False    False    False
# 1229    False    False    False    False    False    False    False    False
#
# [6 rows x 35 columns]

# %%
# 1시가 아닌 windspeed 결측치 - ozone 별로 나누어 median으로 대체
train1['hour_bef_windspeed'].fillna({18:3.2,260:2.5,376:3.5, 780:3.9 ,1138:3.5,1229:3.5}, inplace=True)

# %%
train1.isna().sum()
# Out:
# id                          0
# hour                        0
# hour_bef_temperature        0
# hour_bef_precipitation      0
# hour_bef_windspeed          0
# hour_bef_humidity           0
# hour_bef_visibility         0
# hour_bef_ozone             74
# hour_bef_pm10              88
# hour_bef_pm2.5            115
# count                       0
# hour_0                      0
# hour_1                      0
# hour_2                      0
# hour_3                      0
# hour_4                      0
# hour_5                      0
# hour_6                      0
# hour_7                      0
# hour_8                      0
# hour_9                      0
# hour_10                     0
# hour_11                     0
# hour_12                     0
# hour_13                     0
# hour_14                     0
# hour_15                     0
# hour_16                     0
# hour_17                     0
# hour_18                     0
# hour_19                     0
# hour_20                     0
# hour_21                     0
# hour_22                     0
# hour_23                     0
# dtype: int64

# %% [markdown]
# ##### ozone NA

# %%
# ozone 결측치 확인
train1[train1['hour_bef_ozone'].isna()]
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 14      28     1                  20.0                     0.0
# 44      76    17                  21.7                     0.0
# 46      78     1                  12.2                     0.0
# 84     130     1                   9.4                     0.0
# 122    181    16                  26.2                     0.0
# ...    ...   ...                   ...                     ...
# 1283  1941     1                  16.6                     0.0
# 1322  1994     1                  15.1                     0.0
# 1329  2005     1                  17.7                     0.0
# 1361  2047     1                  12.6                     0.0
# 1391  2086     1                  11.5                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 14                   1.8               58.0               2000.0
# 44                   3.0               35.0               2000.0
# 46                   3.0               49.0               1071.0
# 84                   2.5               65.0               1907.0
# 122                  4.3               31.0               1718.0
# ...                  ...                ...                  ...
# 1283                 2.1               35.0               2000.0
# 1322                 1.3               35.0               2000.0
# 1329                 1.0               43.0               1338.0
# 1361                 2.4               48.0               1805.0
# 1391                 3.2               23.0               2000.0
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  ...  hour_14  hour_15  \
# 14               NaN            NaN             NaN  ...    False    False
# 44               NaN           32.0            19.0  ...    False    False
# 46               NaN            NaN             NaN  ...    False    False
# 84               NaN            NaN             NaN  ...    False    False
# 122              NaN           47.0            23.0  ...    False    False
# ...              ...            ...             ...  ...      ...      ...
# 1283             NaN            NaN             NaN  ...    False    False
# 1322             NaN            NaN             NaN  ...    False    False
# 1329             NaN            NaN             NaN  ...    False    False
# 1361             NaN            NaN             NaN  ...    False    False
# 1391             NaN            NaN             NaN  ...    False    False
#
#       hour_16  hour_17  hour_18  hour_19  hour_20  hour_21  hour_22  hour_23
# 14      False    False    False    False    False    False    False    False
# 44      False     True    False    False    False    False    False    False
# 46      False    False    False    False    False    False    False    False
# 84      False    False    False    False    False    False    False    False
# 122      True    False    False    False    False    False    False    False
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1283    False    False    False    False    False    False    False    False
# 1322    False    False    False    False    False    False    False    False
# 1329    False    False    False    False    False    False    False    False
# 1361    False    False    False    False    False    False    False    False
# 1391    False    False    False    False    False    False    False    False
#
# [74 rows x 35 columns]

# %%
train1.groupby('hour')['hour_bef_ozone'].describe()
# 1시 일때 모두 NAN
# Out:
#       count      mean       std    min      25%     50%      75%    max
# hour
# 0      59.0  0.033763  0.016296  0.003  0.02250  0.0350  0.04250  0.074
# 1       0.0       NaN       NaN    NaN      NaN     NaN      NaN    NaN
# 2      61.0  0.030492  0.016567  0.003  0.01800  0.0310  0.03900  0.083
# 3      61.0  0.031213  0.017270  0.003  0.01800  0.0340  0.04100  0.082
# 4      61.0  0.031984  0.016320  0.004  0.02000  0.0330  0.04100  0.081
# 5      61.0  0.031623  0.015445  0.004  0.02200  0.0320  0.04000  0.077
# 6      60.0  0.029317  0.014817  0.004  0.02000  0.0295  0.03900  0.069
# 7      60.0  0.025300  0.014314  0.003  0.01475  0.0250  0.03325  0.062
# 8      61.0  0.021197  0.012415  0.004  0.01200  0.0210  0.02800  0.061
# 9      61.0  0.021492  0.012475  0.005  0.01200  0.0190  0.02800  0.072
# 10     60.0  0.025167  0.012304  0.005  0.01600  0.0230  0.03225  0.057
# 11     60.0  0.030367  0.013141  0.006  0.01875  0.0305  0.04000  0.061
# 12     60.0  0.036817  0.012920  0.007  0.02775  0.0370  0.04525  0.064
# 13     59.0  0.045203  0.012458  0.011  0.03750  0.0450  0.05400  0.069
# 14     61.0  0.053344  0.014749  0.025  0.04500  0.0500  0.06100  0.090
# 15     60.0  0.057400  0.015086  0.029  0.04650  0.0555  0.06700  0.099
# 16     57.0  0.060579  0.015262  0.029  0.05000  0.0600  0.06900  0.106
# 17     58.0  0.060362  0.015814  0.031  0.05025  0.0590  0.06875  0.112
# 18     59.0  0.058508  0.017437  0.025  0.04900  0.0560  0.06500  0.125
# 19     61.0  0.053967  0.015620  0.022  0.04300  0.0530  0.06200  0.100
# 20     61.0  0.048279  0.015300  0.018  0.04000  0.0480  0.05600  0.100
# 21     60.0  0.043517  0.015631  0.015  0.03275  0.0420  0.05200  0.092
# 22     61.0  0.038066  0.016258  0.006  0.02800  0.0380  0.04800  0.079
# 23     61.0  0.035148  0.015866  0.004  0.02800  0.0360  0.04300  0.070

# %%
plt.plot(train1.groupby('hour_bef_temperature')['hour_bef_ozone'].mean(),color='lightseagreen')
plt.title('mean ozone by temperature')
plt.xlabel('temperature')
plt.ylabel('mean ozone')
# 온도별 평균 ozone
# Out:
# Text(0, 0.5, 'mean ozone')

# %%
plt.scatter(x='hour_bef_temperature',y='hour_bef_ozone',data=train1,color='lightseagreen')

plt.xlabel('temperature')
plt.ylabel('ozone')
plt.show()

# %%
train1.groupby('hour_bef_temperature')['hour_bef_ozone'].mean() # 온도에 따른 ozone
# Out:
# hour_bef_temperature
# 3.1     0.005
# 3.2     0.004
# 3.3     0.016
# 4.0     0.021
# 4.2     0.024
#         ...
# 29.4    0.062
# 29.5    0.057
# 29.6    0.080
# 29.8    0.058
# 30.0    0.100
# Name: hour_bef_ozone, Length: 245, dtype: float64

# %%
train1['hour_bef_temperature'].describe()
# Out:
# count    1457.000000
# mean       16.717433
# std         5.239150
# min         3.100000
# 25%        12.800000
# 50%        16.600000
# 75%        20.100000
# max        30.000000
# Name: hour_bef_temperature, dtype: float64

# %%
# 구간별 온도와 평균 오존농도
tempoz={}
for x in range(3, 31, 1): # 구간은 1도 씩 끊음.
    start = x
    end = x+1
    temp = train1[(train1["hour_bef_temperature"] >= start) & (train1["hour_bef_temperature"] < end)]
    tempoz[start]= temp["hour_bef_ozone"].mean()


# 결측치 구간온도별 오존평균값으로 대체하는 반복문 작성
for i in train1[train1['hour_bef_ozone'].isna()].index:
  a=train1.loc[i,'hour_bef_temperature']
  aa=a//1
  #print(aa,tempoz[aa])
  train1['hour_bef_ozone'].fillna({i:tempoz[aa]},inplace=True)

# %%
train1[train1['hour_bef_ozone'].isna()] # 결측치 제거
# Out:
# Empty DataFrame
# Columns: [id, hour, hour_bef_temperature, hour_bef_precipitation, hour_bef_windspeed, hour_bef_humidity, hour_bef_visibility, hour_bef_ozone, hour_bef_pm10, hour_bef_pm2.5, count, hour_0, hour_1, hour_2, hour_3, hour_4, hour_5, hour_6, hour_7, hour_8, hour_9, hour_10, hour_11, hour_12, hour_13, hour_14, hour_15, hour_16, hour_17, hour_18, hour_19, hour_20, hour_21, hour_22, hour_23]
# Index: []
#
# [0 rows x 35 columns]

# %% [markdown]
# ##### PM10 PM2.5 NA
# pm10 pm2.5 미세먼지 - visibility 로 결측치 대체

# %%
# pm - visibility
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)


sns.scatterplot(x='hour_bef_visibility', y='hour_bef_pm10', data=train1,ax=ax1,color='lightseagreen')
sns.scatterplot(x='hour_bef_visibility', y='hour_bef_pm2.5', data=train1,ax=ax2,color='lightseagreen')
sns.regplot(x='hour_bef_visibility', y='hour_bef_pm2.5', data=train1, fit_reg=True,ax=ax2,color='mediumturquoise')
plt.show()
# Out:
# <Axes: xlabel='hour_bef_visibility', ylabel='hour_bef_pm2.5'>

# %%
train1[train1['hour_bef_pm10'].isna()]
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 14      28     1                  20.0                     0.0
# 46      78     1                  12.2                     0.0
# 84     130     1                   9.4                     0.0
# 100    149    16                  15.8                     0.0
# 129    193    19                  27.0                     0.0
# ...    ...   ...                   ...                     ...
# 1329  2005     1                  17.7                     0.0
# 1338  2016    19                  16.2                     0.0
# 1361  2047     1                  12.6                     0.0
# 1391  2086     1                  11.5                     0.0
# 1398  2096    20                  14.0                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 14                   1.8               58.0               2000.0
# 46                   3.0               49.0               1071.0
# 84                   2.5               65.0               1907.0
# 100                  5.3               17.0               1923.0
# 129                  3.6               39.0               2000.0
# ...                  ...                ...                  ...
# 1329                 1.0               43.0               1338.0
# 1338                 3.5               31.0                950.0
# 1361                 2.4               48.0               1805.0
# 1391                 3.2               23.0               2000.0
# 1398                 2.9               35.0                910.0
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  ...  hour_14  hour_15  \
# 14          0.048357            NaN             NaN  ...    False    False
# 46          0.033188            NaN             NaN  ...    False    False
# 84          0.025082            NaN             NaN  ...    False    False
# 100         0.047000            NaN             NaN  ...    False    False
# 129         0.047000            NaN             NaN  ...    False    False
# ...              ...            ...             ...  ...      ...      ...
# 1329        0.030774            NaN             NaN  ...    False    False
# 1338        0.060000            NaN             NaN  ...    False    False
# 1361        0.033188            NaN             NaN  ...    False    False
# 1391        0.030833            NaN             NaN  ...    False    False
# 1398        0.061000            NaN             NaN  ...    False    False
#
#       hour_16  hour_17  hour_18  hour_19  hour_20  hour_21  hour_22  hour_23
# 14      False    False    False    False    False    False    False    False
# 46      False    False    False    False    False    False    False    False
# 84      False    False    False    False    False    False    False    False
# 100      True    False    False    False    False    False    False    False
# 129     False    False    False     True    False    False    False    False
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1329    False    False    False    False    False    False    False    False
# 1338    False    False    False     True    False    False    False    False
# 1361    False    False    False    False    False    False    False    False
# 1391    False    False    False    False    False    False    False    False
# 1398    False    False    False    False     True    False    False    False
#
# [88 rows x 35 columns]

# %%
print(train1['hour_bef_visibility'].describe())
print()
print(train1['hour_bef_pm10'].describe())
print()
print(train1['hour_bef_pm2.5'].describe())

# outlier 있음 - mean 보다는 median 으로 대체
# Out:
# count    1457.000000
# mean     1405.216884
# std       583.131708
# min        78.000000
# 25%       879.000000
# 50%      1577.000000
# 75%      1994.000000
# max      2000.000000
# Name: hour_bef_visibility, dtype: float64
#
# count    1369.000000
# mean       57.168736
# std        31.771019
# min         9.000000
# 25%        36.000000
# 50%        51.000000
# 75%        69.000000
# max       269.000000
# Name: hour_bef_pm10, dtype: float64
#
# count    1342.000000
# mean       30.327124
# std        14.713252
# min         8.000000
# 25%        20.000000
# 50%        26.000000
# 75%        37.000000
# max        90.000000
# Name: hour_bef_pm2.5, dtype: float64

# %%
sns.boxplot(y='hour_bef_visibility',data=train1)
plt.show()

# %%
# visibility 구간 나누기

tempv10={}
tempv25={}
for x in range(0, 2001 , 100): #100씩 나눈다
    start = x
    end = x+100

    # 0이상 100미만

    tempp = train1[(train1["hour_bef_visibility"] >= start) & (train1["hour_bef_visibility"] < end)]
    tempv10[start]= tempp["hour_bef_pm10"].median()
    tempv25[start]= tempp["hour_bef_pm2.5"].median()


# pm결측치 구간visibility별 미세먼지 median 값으로 대체하는 반복문 작성
for i in train1[train1['hour_bef_pm10'].isna()].index:
  b = train1.loc[i,'hour_bef_visibility']
  bb = (b//100)*100
  train1['hour_bef_pm10'].fillna( {i:tempv10[bb]},inplace=True )

for i in train1[train1['hour_bef_pm2.5'].isna()].index:
  b = train1.loc[i,'hour_bef_visibility']
  bb = (b//100)*100
  train1['hour_bef_pm2.5'].fillna( {i:tempv25[bb]},inplace=True )

# %%
train1[train1['hour_bef_pm10'].isna()]
# Out:
# Empty DataFrame
# Columns: [id, hour, hour_bef_temperature, hour_bef_precipitation, hour_bef_windspeed, hour_bef_humidity, hour_bef_visibility, hour_bef_ozone, hour_bef_pm10, hour_bef_pm2.5, count, hour_0, hour_1, hour_2, hour_3, hour_4, hour_5, hour_6, hour_7, hour_8, hour_9, hour_10, hour_11, hour_12, hour_13, hour_14, hour_15, hour_16, hour_17, hour_18, hour_19, hour_20, hour_21, hour_22, hour_23]
# Index: []
#
# [0 rows x 35 columns]

# %%
train1.isna().sum()
# Out:
# id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            0
# hour_bef_pm10             0
# hour_bef_pm2.5            0
# count                     0
# hour_0                    0
# hour_1                    0
# hour_2                    0
# hour_3                    0
# hour_4                    0
# hour_5                    0
# hour_6                    0
# hour_7                    0
# hour_8                    0
# hour_9                    0
# hour_10                   0
# hour_11                   0
# hour_12                   0
# hour_13                   0
# hour_14                   0
# hour_15                   0
# hour_16                   0
# hour_17                   0
# hour_18                   0
# hour_19                   0
# hour_20                   0
# hour_21                   0
# hour_22                   0
# hour_23                   0
# dtype: int64

# %% [markdown]
# na 없음.

# %%
plt.figure(figsize=(25,25))

mask = np.zeros_like(train1.corr(), dtype=bool)
mask[np.triu_indices_from(mask)] = False

sns.heatmap(train1.corr(),annot=True)
plt.show()

# %% [markdown]
# #### test dataset
# train dataset과 동일한 작업 수행

# %%
test.isna().sum()
# test의 결측치도 대체하기
# Out:
# id                         0
# hour                       0
# hour_bef_temperature       1
# hour_bef_precipitation     1
# hour_bef_windspeed         1
# hour_bef_humidity          1
# hour_bef_visibility        1
# hour_bef_ozone            35
# hour_bef_pm10             37
# hour_bef_pm2.5            36
# dtype: int64

# %%
test1=test

# %%
# 더미변수 생성
tedum = pd.get_dummies(test1['hour'])
test1 = test1.join(tedum.add_prefix('hour_'))
test1
# Out:
#        id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 0       0     7                  20.7                     0.0
# 1       1    17                  30.0                     0.0
# 2       2    13                  19.0                     1.0
# 3       4     6                  22.5                     0.0
# 4       5    22                  14.6                     1.0
# ..    ...   ...                   ...                     ...
# 710  2148     1                  24.6                     0.0
# 711  2149     1                  18.1                     0.0
# 712  2165     9                  23.3                     0.0
# 713  2166    16                  27.0                     0.0
# 714  2177     8                  22.3                     0.0
#
#      hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 0                   1.3               62.0                954.0
# 1                   5.4               33.0               1590.0
# 2                   2.1               95.0                193.0
# 3                   2.5               60.0               1185.0
# 4                   3.4               93.0                218.0
# ..                  ...                ...                  ...
# 710                 2.4               60.0               1745.0
# 711                 1.0               55.0               2000.0
# 712                 2.3               66.0               1789.0
# 713                 1.6               46.0               1956.0
# 714                 1.0               63.0               1277.0
#
#      hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  ...  hour_14  hour_15  \
# 0             0.041           44.0            27.0  ...    False    False
# 1             0.061           49.0            36.0  ...    False    False
# 2             0.020           36.0            28.0  ...    False    False
# 3             0.027           52.0            38.0  ...    False    False
# 4             0.041           18.0            15.0  ...    False    False
# ..              ...            ...             ...  ...      ...      ...
# 710             NaN            NaN             NaN  ...    False    False
# 711             NaN            NaN             NaN  ...    False    False
# 712           0.020           17.0            15.0  ...    False    False
# 713           0.032           40.0            26.0  ...    False    False
# 714           0.007           30.0            24.0  ...    False    False
#
#      hour_16  hour_17  hour_18  hour_19  hour_20  hour_21  hour_22  hour_23
# 0      False    False    False    False    False    False    False    False
# 1      False     True    False    False    False    False    False    False
# 2      False    False    False    False    False    False    False    False
# 3      False    False    False    False    False    False    False    False
# 4      False    False    False    False    False    False     True    False
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 710    False    False    False    False    False    False    False    False
# 711    False    False    False    False    False    False    False    False
# 712    False    False    False    False    False    False    False    False
# 713     True    False    False    False    False    False    False    False
# 714    False    False    False    False    False    False    False    False
#
# [715 rows x 34 columns]

# %%
test1.isna().sum()
# Out:
# id                         0
# hour                       0
# hour_bef_temperature       1
# hour_bef_precipitation     1
# hour_bef_windspeed         1
# hour_bef_humidity          1
# hour_bef_visibility        1
# hour_bef_ozone            35
# hour_bef_pm10             37
# hour_bef_pm2.5            36
# hour_0                     0
# hour_1                     0
# hour_2                     0
# hour_3                     0
# hour_4                     0
# hour_5                     0
# hour_6                     0
# hour_7                     0
# hour_8                     0
# hour_9                     0
# hour_10                    0
# hour_11                    0
# hour_12                    0
# hour_13                    0
# hour_14                    0
# hour_15                    0
# hour_16                    0
# hour_17                    0
# hour_18                    0
# hour_19                    0
# hour_20                    0
# hour_21                    0
# hour_22                    0
# hour_23                    0
# dtype: int64

# %% [markdown]
# ##### temperature NA

# %%
test1[test1['hour_bef_temperature'].isna()]
# Out:
#        id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 653  1943    19                   NaN                     NaN
#
#      hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 653                 NaN                NaN                  NaN
#
#      hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  ...  hour_14  hour_15  \
# 653             NaN            NaN             NaN  ...    False    False
#
#      hour_16  hour_17  hour_18  hour_19  hour_20  hour_21  hour_22  hour_23
# 653    False    False    False     True    False    False    False    False
#
# [1 rows x 34 columns]

# %%
train1[train1['hour_19']==1].describe()
# Out:
#                 id  hour  hour_bef_temperature  hour_bef_precipitation  \
# count    61.000000  61.0             61.000000               61.000000
# mean   1153.147541  19.0             19.704918                0.032787
# std     632.276254   0.0              4.605664                0.179556
# min      55.000000  19.0             10.600000                0.000000
# 25%     601.000000  19.0             16.600000                0.000000
# 50%    1088.000000  19.0             19.400000                0.000000
# 75%    1699.000000  19.0             23.500000                0.000000
# max    2168.000000  19.0             28.700000                1.000000
#
#        hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# count           61.000000           61.00000            61.000000
# mean             3.595082           43.57377          1576.688525
# std              1.153173           19.66084           523.652542
# min              0.700000            8.00000           250.000000
# 25%              3.000000           29.00000          1222.000000
# 50%              3.700000           40.00000          1942.000000
# 75%              4.300000           53.00000          2000.000000
# max              7.000000           92.00000          2000.000000
#
#        hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5       count
# count       61.000000      61.000000       61.000000   61.000000
# mean         0.053967      53.770492       28.327869  201.606557
# std          0.015620      26.547061       13.008614   75.977689
# min          0.022000      17.000000       10.000000    1.000000
# 25%          0.043000      36.000000       19.000000  150.000000
# 50%          0.053000      49.000000       25.000000  204.000000
# 75%          0.062000      67.000000       37.000000  244.000000
# max          0.100000     180.000000       62.000000  335.000000

# %%
# 전부 결측치인 경우 19시 median 값들로 대체
train1[train1['hour']==19]['hour_bef_ozone'].median()
# Out:
# 0.053

# %%
for a in ['hour_bef_temperature','hour_bef_precipitation','hour_bef_windspeed','hour_bef_humidity','hour_bef_visibility','hour_bef_ozone','hour_bef_pm10','hour_bef_pm2.5']:
  test1.loc[653,a]=train1[train1['hour']==19][a].median()

test1.loc[653]
# Out:
# id                          1943
# hour                          19
# hour_bef_temperature        19.4
# hour_bef_precipitation       0.0
# hour_bef_windspeed           3.7
# hour_bef_humidity           40.0
# hour_bef_visibility       1942.0
# hour_bef_ozone             0.053
# hour_bef_pm10               49.0
# hour_bef_pm2.5              25.0
# hour_0                     False
# hour_1                     False
# hour_2                     False
# hour_3                     False
# hour_4                     False
# hour_5                     False
# hour_6                     False
# hour_7                     False
# hour_8                     False
# hour_9                     False
# hour_10                    False
# hour_11                    False
# hour_12                    False
# hour_13                    False
# hour_14                    False
# hour_15                    False
# hour_16                    False
# hour_17                    False
# hour_18                    False
# hour_19                     True
# hour_20                    False
# hour_21                    False
# hour_22                    False
# hour_23                    False
# Name: 653, dtype: object

# %%
test1.isna().sum()
# Out:
# id                         0
# hour                       0
# hour_bef_temperature       0
# hour_bef_precipitation     0
# hour_bef_windspeed         0
# hour_bef_humidity          0
# hour_bef_visibility        0
# hour_bef_ozone            34
# hour_bef_pm10             36
# hour_bef_pm2.5            35
# hour_0                     0
# hour_1                     0
# hour_2                     0
# hour_3                     0
# hour_4                     0
# hour_5                     0
# hour_6                     0
# hour_7                     0
# hour_8                     0
# hour_9                     0
# hour_10                    0
# hour_11                    0
# hour_12                    0
# hour_13                    0
# hour_14                    0
# hour_15                    0
# hour_16                    0
# hour_17                    0
# hour_18                    0
# hour_19                    0
# hour_20                    0
# hour_21                    0
# hour_22                    0
# hour_23                    0
# dtype: int64

# %% [markdown]
# ##### ozone NA

# %%
# ozone
test1[test1['hour_bef_ozone'].isna()]
# Out:
#        id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 32     82     1                  22.8                     0.0
# 40    115     1                  21.5                     1.0
# 47    147     1                  22.8                     0.0
# 86    260     1                  20.0                     0.0
# 92    270     1                  20.0                     0.0
# 102   297     1                  15.1                     1.0
# 114   323     1                  18.7                     0.0
# 126   352     1                  19.2                     0.0
# 129   358     1                  23.6                     0.0
# 209   609     1                  18.6                     0.0
# 212   614    15                  25.2                     0.0
# 223   643     1                  16.8                     0.0
# 272   781     1                  20.1                     0.0
# 307   890     1                  20.9                     0.0
# 353  1034     1                  23.7                     0.0
# 355  1040     1                  24.7                     0.0
# 360  1050     1                  19.5                     0.0
# 386  1122    14                  25.2                     0.0
# 393  1143     1                  21.7                     0.0
# 418  1236     1                  21.6                     0.0
# 419  1237     1                  18.8                     0.0
# 458  1356     1                  23.2                     0.0
# 471  1395     1                  21.4                     0.0
# 492  1462     1                  20.9                     0.0
# 502  1512     1                  21.4                     0.0
# 523  1574     1                  19.5                     0.0
# 620  1857     1                  21.2                     0.0
# 626  1871     1                  22.9                     0.0
# 637  1898    13                  25.8                     0.0
# 642  1913     1                  24.6                     0.0
# 658  1959    14                  28.2                     0.0
# 694  2104     1                  21.7                     0.0
# 710  2148     1                  24.6                     0.0
# 711  2149     1                  18.1                     0.0
#
#      hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 32                  2.4               52.0               2000.0
# 40                  0.5               90.0                347.0
# 47                  1.2               57.0               1190.0
# 86                  2.0               65.0               1662.0
# 92                  1.7               31.0               2000.0
# 102                 2.2               98.0                224.0
# 114                 1.4               41.0               2000.0
# 126                 1.4               80.0               1085.0
# 129                 0.9               83.0                466.0
# 209                 2.4               37.0               2000.0
# 212                 3.7               50.0               1719.0
# 223                 3.6               83.0               1839.0
# 272                 3.1               81.0                266.0
# 307                 0.4               73.0               1218.0
# 353                 2.0               78.0                332.0
# 355                 1.7               48.0               1864.0
# 360                 2.6               42.0               2000.0
# 386                 4.2               48.0               1809.0
# 393                 2.8               77.0               1829.0
# 418                 2.6               81.0               1340.0
# 419                 0.9               72.0                503.0
# 458                 1.5               65.0               1734.0
# 471                 1.8               74.0               1300.0
# 492                 2.5               41.0               2000.0
# 502                 1.1               73.0                713.0
# 523                 2.6               77.0                769.0
# 620                 1.6               68.0                839.0
# 626                 2.6               38.0               2000.0
# 637                 3.1               60.0               1549.0
# 642                 0.6               55.0               2000.0
# 658                 1.8               51.0               1814.0
# 694                 1.7               75.0                957.0
# 710                 2.4               60.0               1745.0
# 711                 1.0               55.0               2000.0
#
#      hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  ...  hour_14  hour_15  \
# 32              NaN            NaN             NaN  ...    False    False
# 40              NaN            NaN             NaN  ...    False    False
# 47              NaN            NaN             NaN  ...    False    False
# 86              NaN            NaN             NaN  ...    False    False
# 92              NaN            NaN             NaN  ...    False    False
# 102             NaN            NaN             NaN  ...    False    False
# 114             NaN            NaN             NaN  ...    False    False
# 126             NaN            NaN             NaN  ...    False    False
# 129             NaN            NaN             NaN  ...    False    False
# 209             NaN            NaN             NaN  ...    False    False
# 212             NaN           32.0            21.0  ...    False     True
# 223             NaN            NaN             NaN  ...    False    False
# 272             NaN            NaN             NaN  ...    False    False
# 307             NaN            NaN             NaN  ...    False    False
# 353             NaN            NaN             NaN  ...    False    False
# 355             NaN            NaN             NaN  ...    False    False
# 360             NaN            NaN             NaN  ...    False    False
# 386             NaN           29.0            13.0  ...     True    False
# 393             NaN            NaN             NaN  ...    False    False
# 418             NaN            NaN             NaN  ...    False    False
# 419             NaN            NaN             NaN  ...    False    False
# 458             NaN            NaN             NaN  ...    False    False
# 471             NaN            NaN             NaN  ...    False    False
# 492             NaN            NaN             NaN  ...    False    False
# 502             NaN            NaN             NaN  ...    False    False
# 523             NaN            NaN             NaN  ...    False    False
# 620             NaN            NaN             NaN  ...    False    False
# 626             NaN            NaN             NaN  ...    False    False
# 637             NaN           21.0            15.0  ...    False    False
# 642             NaN            NaN             NaN  ...    False    False
# 658             NaN           25.0            18.0  ...     True    False
# 694             NaN            NaN             NaN  ...    False    False
# 710             NaN            NaN             NaN  ...    False    False
# 711             NaN            NaN             NaN  ...    False    False
#
#      hour_16  hour_17  hour_18  hour_19  hour_20  hour_21  hour_22  hour_23
# 32     False    False    False    False    False    False    False    False
# 40     False    False    False    False    False    False    False    False
# 47     False    False    False    False    False    False    False    False
# 86     False    False    False    False    False    False    False    False
# 92     False    False    False    False    False    False    False    False
# 102    False    False    False    False    False    False    False    False
# 114    False    False    False    False    False    False    False    False
# 126    False    False    False    False    False    False    False    False
# 129    False    False    False    False    False    False    False    False
# 209    False    False    False    False    False    False    False    False
# 212    False    False    False    False    False    False    False    False
# 223    False    False    False    False    False    False    False    False
# 272    False    False    False    False    False    False    False    False
# 307    False    False    False    False    False    False    False    False
# 353    False    False    False    False    False    False    False    False
# 355    False    False    False    False    False    False    False    False
# 360    False    False    False    False    False    False    False    False
# 386    False    False    False    False    False    False    False    False
# 393    False    False    False    False    False    False    False    False
# 418    False    False    False    False    False    False    False    False
# 419    False    False    False    False    False    False    False    False
# 458    False    False    False    False    False    False    False    False
# 471    False    False    False    False    False    False    False    False
# 492    False    False    False    False    False    False    False    False
# 502    False    False    False    False    False    False    False    False
# 523    False    False    False    False    False    False    False    False
# 620    False    False    False    False    False    False    False    False
# 626    False    False    False    False    False    False    False    False
# 637    False    False    False    False    False    False    False    False
# 642    False    False    False    False    False    False    False    False
# 658    False    False    False    False    False    False    False    False
# 694    False    False    False    False    False    False    False    False
# 710    False    False    False    False    False    False    False    False
# 711    False    False    False    False    False    False    False    False
#
# [34 rows x 34 columns]

# %%
# 구간별 평균 온도와 평균오존농도

tempoz={}
for x in range(3, 31, 1):
    start = x
    end = x+1
    temp = train1[(train1["hour_bef_temperature"] >= start) & (train1["hour_bef_temperature"] < end)]
    tempoz[start]= temp["hour_bef_ozone"].mean()


# 결측치 구간온도별 오존평균값으로 대체하는 반복문 작성
for i in test1[test1['hour_bef_ozone'].isna()].index:
  a=test1.loc[i,'hour_bef_temperature']
  aa=a//1
  test1['hour_bef_ozone'].fillna({i:tempoz[aa]},inplace=True)

# %%
test1[test1['hour_bef_ozone'].isna()]
# Out:
# Empty DataFrame
# Columns: [id, hour, hour_bef_temperature, hour_bef_precipitation, hour_bef_windspeed, hour_bef_humidity, hour_bef_visibility, hour_bef_ozone, hour_bef_pm10, hour_bef_pm2.5, hour_0, hour_1, hour_2, hour_3, hour_4, hour_5, hour_6, hour_7, hour_8, hour_9, hour_10, hour_11, hour_12, hour_13, hour_14, hour_15, hour_16, hour_17, hour_18, hour_19, hour_20, hour_21, hour_22, hour_23]
# Index: []
#
# [0 rows x 34 columns]

# %% [markdown]
# ##### PM10 PM2.5 NA

# %%
test1[test1['hour_bef_pm10'].isna()]
# Out:
#        id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 18     42    18                  29.4                     0.0
# 32     82     1                  22.8                     0.0
# 40    115     1                  21.5                     1.0
# 47    147     1                  22.8                     0.0
# 86    260     1                  20.0                     0.0
# 92    270     1                  20.0                     0.0
# 102   297     1                  15.1                     1.0
# 114   323     1                  18.7                     0.0
# 126   352     1                  19.2                     0.0
# 128   356    15                  25.5                     0.0
# 129   358     1                  23.6                     0.0
# 137   391    15                  29.0                     0.0
# 182   525    13                  31.6                     0.0
# 209   609     1                  18.6                     0.0
# 223   643     1                  16.8                     0.0
# 237   675    19                  29.0                     0.0
# 272   781     1                  20.1                     0.0
# 307   890     1                  20.9                     0.0
# 353  1034     1                  23.7                     0.0
# 355  1040     1                  24.7                     0.0
# 360  1050     1                  19.5                     0.0
# 393  1143     1                  21.7                     0.0
# 418  1236     1                  21.6                     0.0
# 419  1237     1                  18.8                     0.0
# 458  1356     1                  23.2                     0.0
# 471  1395     1                  21.4                     0.0
# 492  1462     1                  20.9                     0.0
# 502  1512     1                  21.4                     0.0
# 523  1574     1                  19.5                     0.0
# 571  1712    16                  25.5                     0.0
# 620  1857     1                  21.2                     0.0
# 626  1871     1                  22.9                     0.0
# 642  1913     1                  24.6                     0.0
# 694  2104     1                  21.7                     0.0
# 710  2148     1                  24.6                     0.0
# 711  2149     1                  18.1                     0.0
#
#      hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 18                  3.3               43.0               1685.0
# 32                  2.4               52.0               2000.0
# 40                  0.5               90.0                347.0
# 47                  1.2               57.0               1190.0
# 86                  2.0               65.0               1662.0
# 92                  1.7               31.0               2000.0
# 102                 2.2               98.0                224.0
# 114                 1.4               41.0               2000.0
# 126                 1.4               80.0               1085.0
# 128                 3.6               40.0               1404.0
# 129                 0.9               83.0                466.0
# 137                 2.9               49.0               1776.0
# 182                 1.2               28.0               1703.0
# 209                 2.4               37.0               2000.0
# 223                 3.6               83.0               1839.0
# 237                 4.0               38.0               1959.0
# 272                 3.1               81.0                266.0
# 307                 0.4               73.0               1218.0
# 353                 2.0               78.0                332.0
# 355                 1.7               48.0               1864.0
# 360                 2.6               42.0               2000.0
# 393                 2.8               77.0               1829.0
# 418                 2.6               81.0               1340.0
# 419                 0.9               72.0                503.0
# 458                 1.5               65.0               1734.0
# 471                 1.8               74.0               1300.0
# 492                 2.5               41.0               2000.0
# 502                 1.1               73.0                713.0
# 523                 2.6               77.0                769.0
# 571                 4.6               45.0               1320.0
# 620                 1.6               68.0                839.0
# 626                 2.6               38.0               2000.0
# 642                 0.6               55.0               2000.0
# 694                 1.7               75.0                957.0
# 710                 2.4               60.0               1745.0
# 711                 1.0               55.0               2000.0
#
#      hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  ...  hour_14  hour_15  \
# 18         0.055000            NaN             NaN  ...    False    False
# 32         0.050830            NaN             NaN  ...    False    False
# 40         0.047054            NaN             NaN  ...    False    False
# 47         0.050830            NaN             NaN  ...    False    False
# 86         0.048357            NaN             NaN  ...    False    False
# 92         0.048357            NaN             NaN  ...    False    False
# 102        0.034958            NaN             NaN  ...    False    False
# 114        0.039660            NaN             NaN  ...    False    False
# 126        0.043236            NaN             NaN  ...    False    False
# 128        0.077000            NaN             NaN  ...    False     True
# 129        0.048978            NaN             NaN  ...    False    False
# 137        0.052000            NaN             NaN  ...    False     True
# 182        0.060000            NaN            29.0  ...    False    False
# 209        0.039660            NaN             NaN  ...    False    False
# 223        0.035425            NaN             NaN  ...    False    False
# 237        0.053000            NaN             NaN  ...    False    False
# 272        0.048357            NaN             NaN  ...    False    False
# 307        0.048357            NaN             NaN  ...    False    False
# 353        0.048978            NaN             NaN  ...    False    False
# 355        0.057519            NaN             NaN  ...    False    False
# 360        0.043236            NaN             NaN  ...    False    False
# 393        0.047054            NaN             NaN  ...    False    False
# 418        0.047054            NaN             NaN  ...    False    False
# 419        0.039660            NaN             NaN  ...    False    False
# 458        0.048978            NaN             NaN  ...    False    False
# 471        0.047054            NaN             NaN  ...    False    False
# 492        0.048357            NaN             NaN  ...    False    False
# 502        0.047054            NaN             NaN  ...    False    False
# 523        0.043236            NaN             NaN  ...    False    False
# 571        0.082000            NaN             NaN  ...    False    False
# 620        0.047054            NaN             NaN  ...    False    False
# 626        0.050830            NaN             NaN  ...    False    False
# 642        0.057519            NaN             NaN  ...    False    False
# 694        0.047054            NaN             NaN  ...    False    False
# 710        0.057519            NaN             NaN  ...    False    False
# 711        0.039660            NaN             NaN  ...    False    False
#
#      hour_16  hour_17  hour_18  hour_19  hour_20  hour_21  hour_22  hour_23
# 18     False    False     True    False    False    False    False    False
# 32     False    False    False    False    False    False    False    False
# 40     False    False    False    False    False    False    False    False
# 47     False    False    False    False    False    False    False    False
# 86     False    False    False    False    False    False    False    False
# 92     False    False    False    False    False    False    False    False
# 102    False    False    False    False    False    False    False    False
# 114    False    False    False    False    False    False    False    False
# 126    False    False    False    False    False    False    False    False
# 128    False    False    False    False    False    False    False    False
# 129    False    False    False    False    False    False    False    False
# 137    False    False    False    False    False    False    False    False
# 182    False    False    False    False    False    False    False    False
# 209    False    False    False    False    False    False    False    False
# 223    False    False    False    False    False    False    False    False
# 237    False    False    False     True    False    False    False    False
# 272    False    False    False    False    False    False    False    False
# 307    False    False    False    False    False    False    False    False
# 353    False    False    False    False    False    False    False    False
# 355    False    False    False    False    False    False    False    False
# 360    False    False    False    False    False    False    False    False
# 393    False    False    False    False    False    False    False    False
# 418    False    False    False    False    False    False    False    False
# 419    False    False    False    False    False    False    False    False
# 458    False    False    False    False    False    False    False    False
# 471    False    False    False    False    False    False    False    False
# 492    False    False    False    False    False    False    False    False
# 502    False    False    False    False    False    False    False    False
# 523    False    False    False    False    False    False    False    False
# 571     True    False    False    False    False    False    False    False
# 620    False    False    False    False    False    False    False    False
# 626    False    False    False    False    False    False    False    False
# 642    False    False    False    False    False    False    False    False
# 694    False    False    False    False    False    False    False    False
# 710    False    False    False    False    False    False    False    False
# 711    False    False    False    False    False    False    False    False
#
# [36 rows x 34 columns]

# %%
# visibility 구간 나누기

tempv10={}
tempv25={}
for x in range(0, 2001 , 100):
    start = x
    end = x+100

    # 0이상 100미만

    tempp = train1[(train1["hour_bef_visibility"] >= start) & (train1["hour_bef_visibility"] < end)]
    tempv10[start]= tempp["hour_bef_pm10"].median()
    tempv25[start]= tempp["hour_bef_pm2.5"].median()


# pm결측치 구간visibility별 미세먼지 median 값으로 대체하는 반복문 작성
for i in test1[test1['hour_bef_pm10'].isna()].index:
  b = test1.loc[i,'hour_bef_visibility']
  bb = (b//100)*100
  test1['hour_bef_pm10'].fillna( {i:tempv10[bb]},inplace=True )

for i in test1[test1['hour_bef_pm2.5'].isna()].index:
  b = test1.loc[i,'hour_bef_visibility']
  bb = (b//100)*100
  test1['hour_bef_pm2.5'].fillna( {i:tempv25[bb]},inplace=True )

# %%
test1.isna().sum()
# Out:
# id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            0
# hour_bef_pm10             0
# hour_bef_pm2.5            0
# hour_0                    0
# hour_1                    0
# hour_2                    0
# hour_3                    0
# hour_4                    0
# hour_5                    0
# hour_6                    0
# hour_7                    0
# hour_8                    0
# hour_9                    0
# hour_10                   0
# hour_11                   0
# hour_12                   0
# hour_13                   0
# hour_14                   0
# hour_15                   0
# hour_16                   0
# hour_17                   0
# hour_18                   0
# hour_19                   0
# hour_20                   0
# hour_21                   0
# hour_22                   0
# hour_23                   0
# dtype: int64

# %% [markdown]
# # Random forest

# %% [markdown]
# random forest 의 옵션 (ctrl+shift)
#
# n_estimators=100, criterion='mse', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='auto', max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=None, random_state=None, verbose=0, warm_start=False, ccp_alpha=0.0, max_samples=None
#
# - n_estimators : n개의 나무들로 학습. 200,300 바꿀 수도 있음
# - n_jobs : cpu 개수. n_jobs=-1 하면 cpu 모두
# - max_depth : 나무의 깊이. overfitting 방지.

# %% [markdown]
# # 모델링

# %% [markdown]
# ## train - train / test split

# %%
features=['hour', 'hour_bef_temperature', 'hour_bef_precipitation',
       'hour_bef_windspeed', 'hour_bef_humidity', 'hour_bef_visibility',
       'hour_bef_ozone', 'hour_bef_pm10', 'hour_bef_pm2.5']

X=train1[features]
y=train1['count']


#train 을 train/test로 분리
from sklearn.model_selection import train_test_split
X_train , X_test ,y_train, y_test= train_test_split(X,y, test_size=0.2)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (1165, 9)
# (292, 9)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()

# %%
rg = RandomForestRegressor()
param={'min_samples_split': [2,5,10],
       'min_samples_leaf':[1,2,4],
        'max_depth': range(10,16),
        'n_estimators': [100,200,300,400],
       'criterion':['squared_error', 'absolute_error']}

# %%
from sklearn.model_selection import GridSearchCV
grid_cv = GridSearchCV(model, param_grid = param, cv = 3)
grid_cv.fit(X_train, y_train)

print('최적 하이퍼 파라미터: ', grid_cv.best_params_)
print('최고 예측 정확도: {:.4f}'.format(grid_cv.best_score_))
# Out:
# 최적 하이퍼 파라미터:  {'criterion': 'squared_error', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 최고 예측 정확도: 0.7687

# %%
pd.DataFrame(grid_cv.cv_results_)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.682952      0.049725         0.018100        0.004279
# 1         1.142243      0.214287         0.027396        0.007882
# 2         1.441969      0.010772         0.033330        0.001072
# 3         2.331871      0.309134         0.063442        0.012508
# 4         0.541447      0.106202         0.013335        0.000697
# ..             ...           ...              ...             ...
# 427       7.591900      0.650717         0.028203        0.001317
# 428       1.646591      0.007245         0.009283        0.000274
# 429       3.738845      0.583226         0.017535        0.004201
# 430       5.332164      0.587405         0.022191        0.000132
# 431       7.983764      0.038457         0.027869        0.000905
#
#     param_criterion param_max_depth param_min_samples_leaf  \
# 0     squared_error              10                      1
# 1     squared_error              10                      1
# 2     squared_error              10                      1
# 3     squared_error              10                      1
# 4     squared_error              10                      1
# ..              ...             ...                    ...
# 427  absolute_error              15                      4
# 428  absolute_error              15                      4
# 429  absolute_error              15                      4
# 430  absolute_error              15                      4
# 431  absolute_error              15                      4
#
#     param_min_samples_split param_n_estimators  \
# 0                         2                100
# 1                         2                200
# 2                         2                300
# 3                         2                400
# 4                         5                100
# ..                      ...                ...
# 427                       5                400
# 428                      10                100
# 429                      10                200
# 430                      10                300
# 431                      10                400
#
#                                                 params  split0_test_score  \
# 0    {'criterion': 'squared_error', 'max_depth': 10...           0.753241
# 1    {'criterion': 'squared_error', 'max_depth': 10...           0.753588
# 2    {'criterion': 'squared_error', 'max_depth': 10...           0.752741
# 3    {'criterion': 'squared_error', 'max_depth': 10...           0.751519
# 4    {'criterion': 'squared_error', 'max_depth': 10...           0.748193
# ..                                                 ...                ...
# 427  {'criterion': 'absolute_error', 'max_depth': 1...           0.732827
# 428  {'criterion': 'absolute_error', 'max_depth': 1...           0.733508
# 429  {'criterion': 'absolute_error', 'max_depth': 1...           0.731823
# 430  {'criterion': 'absolute_error', 'max_depth': 1...           0.730612
# 431  {'criterion': 'absolute_error', 'max_depth': 1...           0.731641
#
#      split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0             0.759728           0.769247         0.760739        0.006573
# 1             0.767149           0.773747         0.764828        0.008392
# 2             0.767268           0.774404         0.764804        0.009014
# 3             0.768523           0.772782         0.764274        0.009186
# 4             0.764007           0.774785         0.762328        0.010921
# ..                 ...                ...              ...             ...
# 427           0.762966           0.756858         0.750884        0.013009
# 428           0.756661           0.753640         0.747936        0.010277
# 429           0.757253           0.755699         0.748258        0.011639
# 430           0.759772           0.756346         0.748910        0.013014
# 431           0.761240           0.752574         0.748485        0.012425
#
#      rank_test_score
# 0                167
# 1                 46
# 2                 47
# 3                 64
# 4                107
# ..               ...
# 427              365
# 428              425
# 429              421
# 430              404
# 431              415
#
# [432 rows x 16 columns]

# %%
grid_cv.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 15,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 100}

# %%
best_rg = grid_cv.best_estimator_
best_rg.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=15)

# %%
from sklearn import metrics
from sklearn.metrics import r2_score

y_pred = best_rg.predict(X_test)
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred)) #MAE
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred)) #MSE
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred))) #
print('R-squared score: ', r2_score(y_test,y_pred))
# Out:
# Mean Absolute Error: 26.33472049660818
# Mean Squared Error: 1454.0180663665842
# Root Mean Squared Error: 38.13158882562572
# R-squared score:  0.778301470105244

# %%
feature_importance = pd.Series(index=features, data=best_rg.feature_importances_).sort_values(ascending=False)
feature_importance.plot(kind='bar', figsize=(24, 5), title="feature importances", rot=0)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## train parameter

# %%
X_train = train1[features]
y_train = train1['count']
X_test = test1[features]

# %%
model_100 = RandomForestRegressor(n_estimators=100, n_jobs = -1)
model_200 = RandomForestRegressor(n_estimators=200, n_jobs = -1)
model_300 = RandomForestRegressor(n_estimators=300, n_jobs = -1)
model_400 = RandomForestRegressor(n_estimators=400, n_jobs = -1)

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(model_100, X_train, y_train)
print(np.mean(score))
score = cross_val_score(model_200, X_train, y_train)
print(np.mean(score))
score = cross_val_score(model_300, X_train, y_train)
print(np.mean(score))
score = cross_val_score(model_400, X_train, y_train)
print(np.mean(score))
# Out:
# 0.7855073652659033
# 0.7839170342183257
# 0.7856786872615429
# 0.7854163056473404

# %%
model_sam_2 = RandomForestRegressor(n_estimators=200, n_jobs = -1,  min_samples_split=2)
model_sam_5 = RandomForestRegressor(n_estimators=200, n_jobs = -1,  min_samples_split=5)
model_sam_10 = RandomForestRegressor(n_estimators=200, n_jobs = -1,  min_samples_split=10)

# %%
score = cross_val_score(model_sam_2, X_train, y_train)
print(np.mean(score))
score = cross_val_score(model_sam_5, X_train, y_train)
print(np.mean(score))
score = cross_val_score(model_sam_10, X_train, y_train)
print(np.mean(score))
# Out:
# 0.7858368077434358
# 0.7817546911817809
# 0.7796092669991517

# %%
model_dep_10 = RandomForestRegressor(n_estimators=200, n_jobs = -1,  min_samples_split=2, max_depth=10)
model_dep_11 = RandomForestRegressor(n_estimators=200, n_jobs = -1,  min_samples_split=2, max_depth=11)
model_dep_12 = RandomForestRegressor(n_estimators=200, n_jobs = -1,  min_samples_split=2, max_depth=12)
model_dep_13 = RandomForestRegressor(n_estimators=200, n_jobs = -1,  min_samples_split=2, max_depth=13)
model_dep_14 = RandomForestRegressor(n_estimators=200, n_jobs = -1,  min_samples_split=2, max_depth=14)
model_dep_15 = RandomForestRegressor(n_estimators=200, n_jobs = -1,  min_samples_split=2, max_depth=15)

# %%
score = cross_val_score(model_dep_10, X_train, y_train)
print(np.mean(score))
score = cross_val_score(model_dep_11, X_train, y_train)
print(np.mean(score))
score = cross_val_score(model_dep_12, X_train, y_train)
print(np.mean(score))
score = cross_val_score(model_dep_13, X_train, y_train)
print(np.mean(score))
score = cross_val_score(model_dep_14, X_train, y_train)
print(np.mean(score))
score = cross_val_score(model_dep_15, X_train, y_train)
print(np.mean(score))
# Out:
# 0.782919812173898
# 0.7829380176493667
# 0.7839245362085452
# 0.785188959749976
# 0.7859894224189308
# 0.7846922669662341

# %% [markdown]
# ## train for submission

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=200, n_jobs = -1,  min_samples_split=2,max_depth=12)

# %%
X_train.shape, y_train.shape, X_test.shape
# Out:
# ((1457, 9), (1457,), (715, 9))

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=12, n_estimators=200, n_jobs=-1)

# %%
submission['count'] = model.predict(X_test)

# %%
submission.to_csv('따릉이data.csv', index = False)
